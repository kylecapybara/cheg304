# %% [markdown]
# ---
# title: cheg304 hw8 q4
# author: author
# date: today
# format:
#     html:
#         self-contained: true
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# from the pareto chart the significant terms are (A, AC, B, AB, C). I can tell this because their effect is greater than the critical effect (the red line labeled 0.401)
#
# also, if the key wants $\alpha=0.1$, like we did in the scouting part of the project, here is that pareto chart, too:
#
# ![image.png](attachment:image.png)
#
# the same conclusions are drawn

# %% [markdown]
# ### two differences
#
# - their printout actually lists p-values since they likely had replicates
# - the shared printout agrees that (A, AC, B, AB, C) are significant
#
# ### two similarities
#
# - the shared printout says ABC and BC are significant, but my minitab output does not

# %%
# filler
