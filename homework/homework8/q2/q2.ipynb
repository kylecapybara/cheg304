# %% [markdown]
# ---
# title: cheg304 hw8 q2
# author: author
# date: today
# format:
#     html:
#         self-contained: true
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <img src="coeffs.png" alt="anova table" width="600"/>
# <img src="anovaa.png" alt="anova table" width="600"/>

# %% [markdown]
# the p values being low (literally displayed as 0.000) means the terms are statistically significant

# %% [markdown]
# # b
#
# to get the 95% CI for the slope we can just adjust the 'fit regression equation' settings
#
# stat > regression > regression > fit regression model > results...
#
# and change the display type to "extended table"
#
# <img src="95p.png" alt="anova table" width="800"/>

# %% [markdown]
# so the 95% CI is
#
# $$
# 95\% \; \mathrm{CI} = (0.08370, 0.11972)
# $$

# %%
#filler
