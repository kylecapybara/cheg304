# %%
import numpy as np
eta = 1/1095
1 - np.exp(-90*eta)
# Out:
# 0.07890470665604521

# %%
import matplotlib.pyplot as plt

x = np.arange(100)
p = 0.05
q = 1-p

def geometricpdf(x):
    return p * q ** x

y = geometricpdf(x)
plt.plot(x,y)

# %%
x = np.linspace(38.66,66,200)
prof = (x - 38.66)*70
def prof(p):
    return (p - 38.66)*70

# %%
prof(63.73)
# Out:
# 1754.9

# %%
from math import comb

np.round(comb(6,1) * comb(19,4) / comb(25,5),3)
# Out:
# 0.438

# %%
comb(5,1) * 0.25 ** 2 * 0.75 **4
# Out:
# 0.098876953125
